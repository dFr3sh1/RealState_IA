# %%
import pandas as pd
import numpy as np

# %%
df_house_set = pd.read_csv("../Brief/df_house_pricing_to_clean.csv")

# %%
df_house_set.loc[df_house_set['yr_renovated'] == 0,'yr_renovated'] = df_house_set['yr_built']

# %%
df_house_set.drop(['yr_built', 'id'], axis=1, inplace=True)

df_house_set
# Out:
#        Unnamed: 0             date      prix  chambres  salles_de_bain  \
# 0               0  20141013T000000  221900.0         3            1.00
# 1               1  20141209T000000  538000.0         3            2.25
# 2               2  20150225T000000  180000.0         2            1.00
# 3               3  20141209T000000  604000.0         4            3.00
# 4               4  20150218T000000  510000.0         3            2.00
# ...           ...              ...       ...       ...             ...
# 21608       21608  20140521T000000  360000.0         3            2.50
# 21609       21609  20150223T000000  400000.0         4            2.50
# 21610       21610  20140623T000000  402101.0         2            0.75
# 21611       21611  20150116T000000  400000.0         3            2.50
# 21612       21612  20141015T000000  325000.0         2            0.75
#
#        m2_habitable   m2_Lot  étages  vue_sur_l-eau  vue  condition  état  \
# ...

# %%
df_house_set.columns
# Out:
# Index(['Unnamed: 0', 'date', 'prix', 'chambres', 'salles_de_bain',
#        'm2_habitable', 'm2_Lot', 'étages', 'vue_sur_l-eau', 'vue', 'condition',
#        'état', 'm2_above', 'm2_cave', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df_house_set.drop(['Unnamed: 0'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df_house_set.drop(['Unnamed: 0'], axis=1, inplace=True)
#       2 df_house_set
#
# File ~/miniconda3/envs/sklearn-env/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/sklearn-env/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df_house_set
# Out:
#                   date      prix  chambres  salles_de_bain  m2_habitable  \
# 0      20141013T000000  221900.0         3            1.00        393.33
# 1      20141209T000000  538000.0         3            2.25        856.67
# 2      20150225T000000  180000.0         2            1.00        256.67
# 3      20141209T000000  604000.0         4            3.00        653.33
# 4      20150218T000000  510000.0         3            2.00        560.00
# ...                ...       ...       ...             ...           ...
# 21608  20140521T000000  360000.0         3            2.50        510.00
# 21609  20150223T000000  400000.0         4            2.50        770.00
# 21610  20140623T000000  402101.0         2            0.75        340.00
# 21611  20150116T000000  400000.0         3            2.50        533.33
# 21612  20141015T000000  325000.0         2            0.75        340.00
#
#         m2_Lot  étages  vue_sur_l-eau  vue  condition  état  m2_above  \
# ...

# %%
df_house_set.to_csv('house_data_for_model.csv')
